# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Type of plots

# %% [markdown]
# ## Line plots

# %%
x=[1,2,3,4,5]
y=[10,20,25,30,40]

# %%
plt.plot(x,y);
plt.title('Simple Line Plot');
plt.xlabel('X-axis label');
plt.ylabel('Y-axis label');
plt.grid(True);

# %% [markdown]
# ## Bar chart

# %%
months=['Jan','Feb','Mar','Apr']
revenue=[100,200,300,500]

# %%
plt.figure(figsize=(10,6));
plt.bar(months,revenue);
plt.title('Monthly revenue bar chart');
plt.xlabel('Months');
plt.ylabel('Revenue');

# %% [markdown]
# ## Histogram

# %%
mark50 = np.random.randint(0,100,50)

# %%
mark50
# Out:
# array([96, 77, 83, 40, 27, 61,  1, 20,  6, 82, 43, 44, 23, 49, 52, 99, 60,
#        33, 22, 48, 58, 41, 96, 59, 93, 70, 92, 64, 86, 82, 19, 39, 60, 86,
#         8, 16, 52, 30, 31, 71, 32, 46, 75, 39, 93, 79, 56, 39, 39, 11],
#       dtype=int32)

# %%
counts, bin_edges, patches=plt.hist(mark50,bins=10, rwidth=0.8);
# Print the bin edges
print("Bin edges:", bin_edges)

# To see the range of each bin:
for i in range(len(bin_edges)-1):
    print(f"Bin {i+1}: {bin_edges[i]} to {bin_edges[i+1]}")

plt.xlabel('Marks');
plt.ylabel('No. of students');
# Out:
# Bin edges: [ 1.  10.8 20.6 30.4 40.2 50.  59.8 69.6 79.4 89.2 99. ]
# Bin 1: 1.0 to 10.8
# Bin 2: 10.8 to 20.6
# Bin 3: 20.6 to 30.400000000000002
# Bin 4: 30.400000000000002 to 40.2
# Bin 5: 40.2 to 50.0
# Bin 6: 50.0 to 59.800000000000004
# Bin 7: 59.800000000000004 to 69.60000000000001
# Bin 8: 69.60000000000001 to 79.4
# Bin 9: 79.4 to 89.2
# Bin 10: 89.2 to 99.0

# %% [markdown]
# ## Scatter plot

# %%
heights=[65,60,70,55,90]
weights=[140,130,150,120,190]
plt.scatter(heights,weights);

# %% [markdown]
# ## Subplots and legends

# %%
days=[1,2,3,4,5]
original_price=[10,20,25,30,40]
predicted_price=[8,21,25,28,38]

# %%
plt.plot(days,original_price, 'b-o', label='Original Price')
plt.plot(days,predicted_price, 'r-o',label='Predicted Price')
plt.legend()
plt.title('Plot with legends')
plt.xlabel('Weekdays')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ## Subplots

# %%
# First subplot - Original Price
plt.subplot(3,1,1);
plt.plot(days,original_price, 'b-o', label='Original Price')
plt.title('Original prices over time')
plt.xlabel('Weekdays')
plt.ylabel('Price')
plt.legend()

# Second subplot - Predicted Price
plt.subplot(3,1,2);
plt.plot(days,predicted_price, 'r-o',label='Predicted Price')
plt.title('Predicted prices over time')
plt.xlabel('Weekdays')
plt.ylabel('Price')
plt.legend()

# Third subplot - Difference between Original & Predicted Price
price_difference = [o - p for o, p in zip(original_price, predicted_price)]
plt.subplot(3,1,3);
plt.bar(days,price_difference, color='purple',label='Price Difference')
plt.title('Difference between Original & Predicted Price')
plt.xlabel('Days')
plt.ylabel('Price Difference')
plt.legend()

plt.tight_layout()

# %% [markdown]
# ## Saving the figure

# %%
plt.plot(days,original_price, 'b-o', label='Original Price')
plt.plot(days,predicted_price, 'r-o',label='Predicted Price')
plt.legend()
plt.title('Plot with legends')
plt.xlabel('Weekdays')
plt.ylabel('Price')
plt.savefig('example_prediction.png',dpi=300) # save the image

# %% [markdown]
# ## Plots using Pandas DataFrame

# %%
# Loading data with Pandas
df = pd.read_csv('auto_sales_data.csv')
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10168               36      96.66                1  3479.76
# ...           ...              ...        ...              ...      ...
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#        ORDERDATE  DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  \
# 0     24/02/2018                   828   Shipped  Motorcycles    95
# 1     07/05/2018                   757   Shipped  Motorcycles    95
# 2     01/07/2018                   703   Shipped  Motorcycles    95
# 3     25/08/2018                   649   Shipped  Motorcycles    95
# 4     28/10/2018                   586   Shipped  Motorcycles    95
# ...          ...                   ...       ...          ...   ...
# 2742  02/12/2019                  2924   Shipped        Ships    54
# 2743  31/01/2020                  2865   Shipped        Ships    54
# 2744  01/03/2020                  2836  Resolved        Ships    54
# 2745  28/03/2020                  2810   Shipped        Ships    54
# 2746  06/05/2020                  2772   On Hold        Ships    54
#
#      PRODUCTCODE             CUSTOMERNAME             PHONE  \
# 0       S10_1678        Land of Toys Inc.        2125557818
# 1       S10_1678       Reims Collectables        26.47.1555
# 2       S10_1678          Lyon Souveniers  +33 1 46 62 7555
# 3       S10_1678        Toys4GrownUps.com        6265557265
# 4       S10_1678     Technics Stores Inc.        6505556809
# ...          ...                      ...               ...
# 2742    S72_3212    Euro Shopping Channel    (91) 555 94 44
# 2743    S72_3212  Oulu Toy Supplies, Inc.        981-443655
# 2744    S72_3212    Euro Shopping Channel    (91) 555 94 44
# 2745    S72_3212             Alpha Cognac        61.77.6555
# 2746    S72_3212        Gifts4AllAges.com        6175559555
#
#                        ADDRESSLINE1        CITY POSTALCODE  COUNTRY  \
# 0           897 Long Airport Avenue         NYC      10022      USA
# 1                59 rue de l'Abbaye       Reims      51100   France
# 2     27 rue du Colonel Pierre Avia       Paris      75508   France
# 3                78934 Hillside Dr.    Pasadena      90003      USA
# 4                 9408 Furth Circle  Burlingame      94217      USA
# ...                             ...         ...        ...      ...
# 2742             C/ Moralzarzal, 86      Madrid      28034    Spain
# 2743                    Torikatu 38        Oulu      90110  Finland
# 2744             C/ Moralzarzal, 86      Madrid      28034    Spain
# 2745          1 rue Alsace-Lorraine    Toulouse      31000   France
# 2746             8616 Spinnaker Dr.      Boston      51003      USA
#
#      CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0                 Yu             Kwai    Small
# 1            Henriot             Paul    Small
# 2           Da Cunha           Daniel   Medium
# 3              Young            Julie   Medium
# 4             Hirano             Juri   Medium
# ...              ...              ...      ...
# 2742          Freyre            Diego    Small
# 2743       Koskitalo           Pirkko   Medium
# 2744          Freyre            Diego   Medium
# 2745          Roulet          Annette    Small
# 2746         Yoshido             Juri   Medium
#
# [2747 rows x 20 columns]

# %%
plt.bar(df['PRODUCTLINE'],df['SALES']);
plt.xticks(rotation=45,ha='center');

# %%
df=pd.read_csv('TSLA.csv')
df
# Out:
#             Date         Open         High         Low        Close  \
# 0     2010-06-29     3.800000     5.000000    3.508000     4.778000
# 1     2010-06-30     5.158000     6.084000    4.660000     4.766000
# 2     2010-07-01     5.000000     5.184000    4.054000     4.392000
# 3     2010-07-02     4.600000     4.620000    3.742000     3.840000
# 4     2010-07-06     4.000000     4.000000    3.166000     3.222000
# ...          ...          ...          ...         ...          ...
# 2951  2022-03-18   874.489990   907.849976  867.390015   905.390015
# 2952  2022-03-21   914.979980   942.849976  907.090027   921.159973
# 2953  2022-03-22   930.000000   997.859985  921.750000   993.979980
# 2954  2022-03-23   979.940002  1040.699951  976.400024   999.109985
# 2955  2022-03-24  1009.729980  1024.489990  988.799988  1013.919983
#
#         Adj Close    Volume
# 0        4.778000  93831500
# 1        4.766000  85935500
# 2        4.392000  41094000
# 3        3.840000  25699000
# 4        3.222000  34334500
# ...           ...       ...
# 2951   905.390015  33408500
# 2952   921.159973  27327200
# 2953   993.979980  35289500
# 2954   999.109985  40225400
# 2955  1013.919983  22901900
#
# [2956 rows x 7 columns]

# %%
plt.plot(df.Close)
