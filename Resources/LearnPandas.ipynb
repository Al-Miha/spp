# %%
import pandas as pd

# %%
df=pd.read_csv('call_activity.csv')
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['State']
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
type(df['State'])
# Out:
# pandas.core.series.Series

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %% [markdown]
# ## Create a DataFrame from a Dictionary

# %%
tempDict={
    'Name':["John","Mike","Robert"],
    'Designation':['Software Engineer','Video Editor','Accountant'],
    'Salary':[10000,20000,30000]
}

# %%
dictDf = pd.DataFrame.from_dict(tempDict)

# %%
dictDf
# Out:
#      Name        Designation  Salary
# 0    John  Software Engineer   10000
# 1    Mike       Video Editor   20000
# 2  Robert         Accountant   30000

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls           float64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls           float64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls         float64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls    float64
# Churn                      object
# dtype: object

# %%
df.State
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
df.State.unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
df[df['International plan']=='Yes']
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# 5       AL             118        510                Yes              No
# 7       MO             147        415                Yes              No
# 9       WV             141        415                Yes             Yes
# ...    ...             ...        ...                ...             ...
# 3304    IL              71        510                Yes              No
# 3309    VT             100        408                Yes              No
# 3317    SD             163        415                Yes              No
# 3320    GA             122        510                Yes              No
# 3331    CT             184        510                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df[(df['International plan']=='Yes') & (df['Churn']==True)]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 41      MD             135        408                Yes             Yes
# 115     ME              36        510                Yes             Yes
# 144     VT             117        408                Yes              No
# 198     ME             131        510                Yes             Yes
# 214     FL              70        510                Yes              No
# ...    ...             ...        ...                ...             ...
# 3246    NC              77        408                Yes             Yes
# 3255    RI             138        510                Yes              No
# 3291    MI             119        510                Yes             Yes
# 3304    IL              71        510                Yes              No
# 3320    GA             122        510                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df[(df['International plan']=='Yes') & (df['Total day charge']>31)]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3       OH              84        408                Yes              No
# 5       AL             118        510                Yes              No
# 9       WV             141        415                Yes             Yes
# 66      WY              43        415                Yes              No
# 81      OR             116        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3269    WV             117        510                Yes              No
# 3304    IL              71        510                Yes              No
# 3309    VT             100        408                Yes              No
# 3317    SD             163        415                Yes              No
# 3331    CT             184        510                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.iloc[9]
# Out:
# State                        WV
# Account length              141
# Area code                   415
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        37
# Total day minutes         258.6
# Total day calls            84.0
# Total day charge          43.96
# Total eve minutes         222.0
# Total eve calls           111.0
# Total eve charge          18.87
# Total night minutes       326.4
# Total night calls          97.0
# Total night charge        14.69
# Total intl minutes         11.2
# Total intl calls              5
# Total intl charge          3.02
# Customer service calls      0.0
# Churn                     False
# Name: 9, dtype: object

# %%
df.iloc[9,2]
# Out:
# np.int64(415)

# %%
df.iloc[3:10]
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
# 7    MO             147        415                Yes              No
# 8    LA             117        408                 No              No
# 9    WV             141        415                Yes             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
# 5                      0              223.4             98.0
# 6                     24              218.2             88.0
# 7                      0              157.0             79.0
# ...

# %%
state=df.copy()
state.set_index('State',inplace=True)

# %%
state.head()
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# KS                128        415                 No             Yes
# OH                107        415                 No             Yes
# NJ                137        415                 No              No
# OH                 84        408                Yes              No
# OK                 75        415                Yes              No
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# KS                        25              265.1            110.0
# OH                        26              161.6            123.0
# NJ                         0              243.4            114.0
# OH                         0              299.4             71.0
# OK                         0              166.7            113.0
#
#        Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# State
# ...

# %%
state.loc['NJ']
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# NJ                137        415                 No              No
# NJ                149        408                 No              No
# NJ                138        408                 No              No
# NJ                128        415                 No              No
# NJ                 64        510                 No              No
# ...               ...        ...                ...             ...
# NJ                 75        415                 No             Yes
# NJ                108        415                 No              No
# NJ                107        408                 No             Yes
# NJ                 93        415                 No              No
# NJ                139        415                 No             Yes
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# NJ                         0              243.4            114.0
# ...

# %%
state.reset_index()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.isnull().sum()
# Out:
# State                      0
# Account length             0
# Area code                  0
# International plan         0
# Voice mail plan            0
# Number vmail messages      0
# Total day minutes         10
# Total day calls           10
# Total day charge          18
# Total eve minutes          9
# Total eve calls            8
# Total eve charge           0
# Total night minutes        0
# Total night calls          1
# Total night charge         0
# Total intl minutes         0
# Total intl calls           0
# Total intl charge          5
# Customer service calls     5
# Churn                      8
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
df.drop('Total night minutes',axis=1)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df['New Column']=df['Total day charge']+df['Total eve charge']

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.iloc[1,1]
# Out:
# np.int64(107)

# %%
df.to_csv('output.csv')

# %%
dictDf.to_json()
# Out:
# '{"Name":{"0":"John","1":"Mike","2":"Robert"},"Designation":{"0":"Software Engineer","1":"Video Editor","2":"Accountant"},"Salary":{"0":10000,"1":20000,"2":30000}}'
